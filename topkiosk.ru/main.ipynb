# %%
a = [
    {
        "product_name": "Утепленный, быстровозводимый  павильон 10*5м",
        "product_href": "https://topkiosk.ru/wp-content/uploads/2019/10/BAY_8136.jpg"
    },
    {
        "product_name": "Торговый павильон под мясную продукцию",
        "product_href": "https://topkiosk.ru/wp-content/uploads/2019/10/torgovyy-pavilon-pod-myasnuyu-produkciyu.jpg"
    },
    {
        "product_name": "Павильон мясной со входом.  Большая угловая витрина.",
        "product_href": "https://topkiosk.ru/wp-content/uploads/2019/10/BAY_8132.jpg"
    },
    {
        "product_name": "Торговый ряд Видное",
        "product_href": "https://topkiosk.ru/wp-content/uploads/2023/11/bay_9378_1_900-scaled.jpg"
    },
    {
        "product_name": "Торговый ряд 425кв.м Купелинка.",
        "product_href": "https://topkiosk.ru/wp-content/uploads/2023/11/bay_9408_1_900.jpg"
    },
    {
        "product_name": "Утепленный, быстровозводимый  павильон 10*5м",
        "product_href": "https://topkiosk.ru/wp-content/uploads/2019/10/BAY_8136.jpg"
    }, 
    {
        "product_name": "Утепленный, быстровозводимый  павильон 10*5м",
        "product_href": "https://topkiosk.ru/wp-content/uploads/2019/10/BAY_8136.jpg"
    }]
b = 0

# for i in a:
    for j in a[b:b+3]:
        print(j)
    print("="*30)
    b+=3
# Out:
# {'product_name': 'Утепленный, быстровозводимый  павильон 10*5м', 'product_href': 'https://topkiosk.ru/wp-content/uploads/2019/10/BAY_8136.jpg'}
# {'product_name': 'Торговый павильон под мясную продукцию', 'product_href': 'https://topkiosk.ru/wp-content/uploads/2019/10/torgovyy-pavilon-pod-myasnuyu-produkciyu.jpg'}
# {'product_name': 'Павильон мясной со входом.  Большая угловая витрина.', 'product_href': 'https://topkiosk.ru/wp-content/uploads/2019/10/BAY_8132.jpg'}
# ...
# {'product_name': 'Торговый ряд Видное', 'product_href': 'https://topkiosk.ru/wp-content/uploads/2023/11/bay_9378_1_900-scaled.jpg'}
# {'product_name': 'Торговый ряд 425кв.м Купелинка.', 'product_href': 'https://topkiosk.ru/wp-content/uploads/2023/11/bay_9408_1_900.jpg'}
# {'product_name': 'Утепленный, быстровозводимый  павильон 10*5м', 'product_href': 'https://topkiosk.ru/wp-content/uploads/2019/10/BAY_8136.jpg'}
# ...
